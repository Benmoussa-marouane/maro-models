# %%
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-18415aa480d1> in <module>()
#      39 import time
#      40 import sys
# ---> 41 from datapreprocess import badzeros   ## local library datapreprocess.py
#      42
#      43 # convert an array of values into a dataset matrix
#
# ModuleNotFoundError: No module named 'datapreprocess'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
